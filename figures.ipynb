# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs  #类数据的生成
X, y = make_blobs(n_samples=50,n_features=2,centers = 2,
                  random_state=0, cluster_std=0.60)
print(X.shape)	#完全是自己想看一看X的格式
plt.scatter(X[:, 0], X[:, 1], c=y, s=50,marker='o',cmap='summer')
plt.figure(figsize = (10,6))
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plt.plot([0.6], [2.1], 'x', color='blue', markeredgewidth=3, markersize=10)

for m, b in [(1.1, 0.65), (0.5, 1.6), (-0.2, 2.9)]:
    plt.plot(xfit, m * xfit + b,)

plt.xlim(-1, 3.5)
plt.figure(figsize = (8,5))
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')

for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]:
    yfit = m * xfit + b
    plt.plot(xfit, yfit, )
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='blue',
                     color='#AAAAAA', alpha=0.5)

plt.xlim(-1, 3.5);
# Out:
# (50, 2)

# %%
from sklearn.svm import SVC    # "Support vector classifier"
model = SVC(kernel='linear')   #kernel选择线性的
model.fit(X, y)
# Out:
# SVC(kernel='linear')

# %%
# #绘图函数
# def plot_svc_decision_function(model, ax=None, plot_support=True):
#     """Plot the decision function for a 2D SVC"""
#     if ax is None:
#         ax = plt.gca()
#     xlim = ax.get_xlim()
#     ylim = ax.get_ylim()
#
#     # create grid to evaluate model
#     x = np.linspace(xlim[0], xlim[1], 30)
#     y = np.linspace(ylim[0], ylim[1], 30)
#     Y, X = np.meshgrid(y, x)
#     xy = np.vstack([X.ravel(), Y.ravel()]).T
#     P = model.decision_function(xy).reshape(X.shape)
#
#     # plot decision boundary and margins
#     ax.contour(X, Y, P, colors='k',
#                levels=[-1, 0, 1], alpha=0.5,
#                linestyles=['--', '-', '--'])
#
#     # plot support vectors
#     if plot_support:
#         ax.scatter(model.support_vectors_[:, 0],
#                    model.support_vectors_[:, 1],
#                    s=300, linewidth=1, facecolors='black');
#     ax.set_xlim(xlim)
#     ax.set_ylim(ylim)
# plt.figure(figsize = (10,8))
# plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
# plot_svc_decision_function(model)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import torch
from lightcurve import LightCurve

lc = torch.load('data/new_tensor_data/ASASSN-VJ000009.88+612904.7.pth')
# plt.figure(figsize=(20, 6))
# plt.scatter(range(seq_len), ls)
# plt.show()
lc

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-29-21-09-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64].csv'
df = pd.read_csv(filename)
plt.title(filename)
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, label='train')
plt.plot(df['epoch'], df['test_loss'],color='red',alpha=0.5,label='test')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-29-21-09-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64].csv'
filename_2 = 'data/train_loss/2023-03-29-21-26-types[LSTM]-times[1500]-dropout[0.25]-batchsize[128].csv'
filename_3 = 'data/train_loss/2023-03-29-17-20-types[LSTM]-times[1500]-dropout[0.25]-batchsize[32].csv'
filename_4 = 'data/train_loss/2023-03-29-22-30-types[LSTM]-times[1500]-dropout[0.25]-batchsize[16].csv'


df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)
df_4 = pd.read_csv(filename_4)

plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df_4['epoch'], df_4['test_loss'],color='orange', label = 'batchsize[16]', linewidth=0.8)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'batchsize[32]', linewidth=0.5)
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'batchsize[64]', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df_2['epoch'], df_2['test_loss'],color='green', label = 'batchsize[128]', linewidth=0.5)

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-04-16-23-10-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[64]-numlayer[2]--pretrain.csv'
filename_2 = 'data/train_loss/2023-04-16-22-52-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[64]-numlayer[1]--pretrain.csv'
filename_3 = 'data/train_loss/2023-04-16-23-29-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[64]-numlayer[3]--pretrain.csv'
filename_4 = 'data/train_loss/2023-04-16-23-47-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[64]-numlayer[4]--pretrain.csv'


df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)
df_4 = pd.read_csv(filename_4)

plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df_2['epoch'], df_2['test_loss'],color='green', label = 'numlayer[1]', linewidth=0.3, alpha=0.5)
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'numlayer[2]', linewidth=0.3)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'numlayer[3]', linewidth=0.3, alpha=0.5)
plt.plot(df_4['epoch'], df_4['test_loss'],color='orange', label = 'numlayer[4]', linewidth=0.3, alpha=0.5)

# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)


plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-31-05-55-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]--formal.csv'
filename_2 = 'data/train_loss/2023-04-17-13-32-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[64]-numlayer[3]--formal.csv'
filename_3 = 'data/train_loss/2023-04-17-14-59-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[64]-numlayer[4]--formal.csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)

plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'numlayer[2]', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df_2['epoch'], df_2['test_loss'],color='green', label = 'numlayer[3]', linewidth=0.5)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'numlayer[4]', linewidth=0.5)
plt.xlim(0,190)
plt.ylim(0.26,0.45)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-29-21-09-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64].csv'
filename_2 = 'data/train_loss/2023-03-29-23-22-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64]-hiddensize[96].csv'
filename_3 = 'data/train_loss/2023-03-29-23-42-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64]-hiddensize[128].csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)

plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'hiddensize[64]', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df_2['epoch'], df_2['test_loss'],color='green',label = 'hiddensize[96]', linewidth=0.5)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'hiddensize[128]', linewidth=0.5)

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-29-21-09-types[LSTM]-times[1500]-dropout[0.25]-batchsize[64].csv'
filename_2 = 'data/train_loss/2023-03-30-00-29-types[LSTM]-times[1500]-dropout[0]-batchsize[64]-hiddensize[64].csv'
filename_3 = 'data/train_loss/2023-03-30-00-10-types[LSTM]-times[1500]-dropout[0.75]-batchsize[64]-hiddensize[64].csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)

plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'dropout[0.25]', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df_2['epoch'], df_2['test_loss'],color='green', label = 'dropout[0]', linewidth=0.5)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'dropout[0.75]', linewidth=0.5)

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-31-05-55-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]--formal.csv'
filename_2 = 'data/train_loss/2023-04-17-00-33-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[64]-numlayer[3]--formal.csv'
filename_3 = 'data/train_loss/2023-04-17-01-04-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[64]-numlayer[4]--formal.csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)

plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'numlayer[2]', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df_2['epoch'], df_2['test_loss'],color='green', label = 'numlayer[3]', linewidth=0.5)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'numlayer[4]', linewidth=0.5)
# plt.xlim(20,180)
# plt.ylim(0.27,0.28)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
ls1 = []
ls2 = []
with open('F:\\OneDrive\\BNU\\0.1final\\1.txt','r') as f:
    while True:
        try:
            strs = f.readline()
            # print(strs)
            l1, l2 = strs.split(' ')[-2:]
            ls1.append(float(l1))
            ls2.append(float(l2))
        except Exception as e:
            print(e)
            break
plt.plot(range(len(ls1)), ls1,color='blue', label = 'train loss', linewidth=0.5)
plt.plot(range(len(ls2)), ls2,color='orange', label = 'test loss', linewidth=0.5)
plt.xlim(50,300)
plt.ylim(0.27,0.28)

plt.legend()
plt.show()
# Out:
# not enough values to unpack (expected 2, got 1)

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-31-05-24-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]--formal.csv'
filename_2 = 'data/train_loss/2023-03-31-05-55-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]--formal.csv'
filename_3 = 'data/train_loss/2023-03-31-15-00-types[LSTM]-times[180]-dropout[0.75]-batchsize[64]-hiddensize[64]-outputsize[64]--formal.csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)

plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'dropout[0.25]-1', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df_2['epoch'], df_2['test_loss'],color='green', label = 'dropout[0.25]-2', linewidth=0.5)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'dropout[0.75]', linewidth=0.5)


plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-31-05-55-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]--formal.csv'
filename_2 = 'data/train_loss/2023-03-31-07-07-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[128]--formal.csv'
filename_3 = 'data/train_loss/2023-03-31-11-32-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[256]--formal.csv'
filename_4 = 'data/train_loss/2023-03-31-12-58-types[LSTM]-times[80]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[512]--formal.csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)
df_4 = pd.read_csv(filename_4)


plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'output size[64]', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df_2['epoch'], df_2['test_loss'],color='green', label = 'output size[128]', linewidth=0.5)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'output size[256]', linewidth=0.5)
plt.plot(df_4['epoch'], df_4['test_loss'],color='orange', label = 'output size[512]', linewidth=0.5)

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/train_loss/2023-03-31-05-55-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]--formal.csv'
filename_2 = 'data/train_loss/2023-03-31-17-38-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[96]-outputsize[64]--formal.csv'
filename_3 = 'data/train_loss/2023-04-01-19-02-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[128]-outputsize[64]--formal.csv'
filename_4 = 'data/train_loss/2023-04-01-17-51-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[256]-outputsize[64]--formal.csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)
df_4 = pd.read_csv(filename_4)


plt.title('epoch-test loss')
plt.xlabel('epoch')
plt.ylabel('loss')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['epoch'], df['test_loss'],color='red', label = 'hidden size[64]', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df_2['epoch'], df_2['test_loss'],color='green', label = 'hidden size[96]', linewidth=0.5)
plt.plot(df_3['epoch'], df_3['test_loss'],color='blue', label = 'hidden size[128]', linewidth=0.5)
plt.plot(df_4['epoch'], df_4['test_loss'],color='orange', label = 'hidden size[256]', linewidth=0.5)
plt.xlim(0,190)
plt.ylim(0.26,0.3)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
filename='data/acc_svm/2023-04-02-00-26-types[svm]-times[500-3000]+-hiddensize[64--formal.csv'
filename_2 = 'data/acc_svm/2023-04-02-00-39-types[svm]-times[500-3000]+-hiddensize[64]-outputsize[64.csv'
filename_3 = 'data/acc_svm/2023-04-02-00-52-types[svm]-times[500-3000]+-hiddensize[64]-outputsize[128.csv'
filename_4 = 'data/acc_svm/2023-04-02-01-17-types[svm]-times[500-3000]+-hiddensize[64]-outputsize[512.csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)
df_4 = pd.read_csv(filename_4)

plt.xlabel('iter')
plt.ylabel('acc')
plt.plot(df['iter'], df['test_acc'],color='red', label = 'output size[64]', linewidth=0.5)
plt.plot(df_2['iter'], df_2['test_acc'],color='green', label = 'output size[128]', linewidth=0.5)
plt.plot(df_3['iter'], df_3['test_acc'],color='blue', label = 'output size[256]', linewidth=0.5)
plt.plot(df_4['iter'], df_4['test_acc'],color='orange', label = 'output size[512]', linewidth=0.5)

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/acc_svm/2023-04-02-16-51-types[rbf]-times[2000]-outputsize[64]-gamma[scale].csv'
filename_2 = 'data/acc_svm/2023-04-02-16-53-types[linear]-times[2000]-outputsize[64]-gamma[scale].csv'
filename_3 = 'data/acc_svm/2023-04-02-16-56-types[poly]-times[2000]-outputsize[64]-gamma[scale].csv'
filename_4 = 'data/acc_svm/2023-04-02-17-02-types[sigmoid]-times[2000]-outputsize[64]-gamma[scale].csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)
df_4 = pd.read_csv(filename_4)

plt.xlabel('C')
plt.ylabel('acc')
plt.title('output 64')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['C']/2, df['train_acc'],color='red', label = 'rbf train', linewidth=0.5, marker='o',markersize='5')
plt.plot(df['C']/2, df['test_acc'],color='red', label = 'rbf test', linewidth=0.5, marker='v',markersize='5')

plt.plot(df_2['C']/2, df_2['train_acc'],color='green',  label = 'linear train', linewidth=0.5, marker='o',markersize='5')
plt.plot(df_2['C']/2, df_2['test_acc'],color='green',  label = 'linear test', linewidth=0.5, marker='v',markersize='5')

plt.plot(df_3['C']/2, df_3['train_acc'],color='blue',  label = 'poly train', linewidth=0.5, marker='o',markersize='5')
plt.plot(df_3['C']/2, df_3['test_acc'],color='blue',  label = 'poly test', linewidth=0.5, marker='v',markersize='5')

plt.plot(df_4['C']/2, df_4['train_acc'],color='orange',  label = 'sigmoid train', linewidth=0.5, marker='o',markersize='5')
plt.plot(df_4['C']/2, df_4['test_acc'],color='orange',  label = 'sigmoid test', linewidth=0.5, marker='v',markersize='5')

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/acc_svm/2023-04-02-17-31-types[rbf]-times[2000]-outputsize[256]-gamma[scale].csv'
filename_2 = 'data/acc_svm/2023-04-02-23-31-types[linear]-times[2000]-outputsize[256]-gamma[scale].csv'
filename_3 = 'data/acc_svm/2023-04-03-00-16-types[poly]-times[2000]-outputsize[256]-gamma[scale].csv'
filename_4 = 'data/acc_svm/2023-04-03-00-32-types[sigmoid]-times[2000]-outputsize[256]-gamma[scale].csv'

df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)
df_4 = pd.read_csv(filename_4)

plt.xlabel('C')
plt.ylabel('acc')
plt.title('output 256')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['C']/2, df['train_acc'],color='red', label = 'rbf train', linewidth=0.5, marker='o',markersize='5')
plt.plot(df['C']/2, df['test_acc'],color='red', label = 'rbf test', linewidth=0.5, marker='v',markersize='5')

plt.plot(df_2['C']/2, df_2['train_acc'],color='green',  label = 'linear train', linewidth=0.5, marker='o',markersize='5')
plt.plot(df_2['C']/2, df_2['test_acc'],color='green',  label = 'linear test', linewidth=0.5, marker='v',markersize='5')

plt.plot(df_3['C']/2, df_3['train_acc'],color='blue',  label = 'poly train', linewidth=0.5, marker='o',markersize='5')
plt.plot(df_3['C']/2, df_3['test_acc'],color='blue',  label = 'poly test', linewidth=0.5, marker='v',markersize='5')

plt.plot(df_4['C']/2, df_4['train_acc'],color='orange',  label = 'sigmoid train', linewidth=0.5, marker='o',markersize='5')
plt.plot(df_4['C']/2, df_4['test_acc'],color='orange',  label = 'sigmoid test', linewidth=0.5, marker='v',markersize='5')

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/acc_svm/2023-04-03-09-26-types[rbf]-times[2000]-outputsize[256]-gamma[scale].csv'


df = pd.read_csv(filename)
df_2 = pd.read_csv(filename_2)
df_3 = pd.read_csv(filename_3)
df_4 = pd.read_csv(filename_4)

plt.xlabel('C')
plt.ylabel('acc')
plt.title('output 256')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['C']/10, df['test_acc'])

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import matplotlib.pyplot as plt

filename = 'data/acc_svm/2023-04-05-01-31-types[rbf]-times[3000]-outputsize[64]-gamma[0.05].csv'

df = pd.read_csv(filename)
plt.xlabel('iter')
plt.ylabel('acc')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['C'], df['train_acc'], color='red', label='train acc', linewidth=0.5)
# plt.plot(df_2['epoch'], df_2['loss'],color='blue',alpha=0.5)
plt.plot(df['C'], df['test_acc'], color='green', label='test acc', linewidth=0.5)
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
filename='data/acc_svm/2023-04-16-22-28-types[ELM]-times[2000]-outputsize[256]-[tanh].csv'


df = pd.read_csv(filename)

plt.xlabel('n_neurons')
plt.ylabel('train_acc')
plt.title('ELM acc')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.plot(df['n_neurons'], df['train_acc'], label = 'train')
plt.plot(df['n_neurons'], df['test_acc'], label = 'test')

plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator

xgboost='data/2023-04-18-10-39-types[rbf]-times[2000]-outputsize[256]-gamma[scale]-[xgboost_time].csv'
svm = 'data/2023-04-18-10-49-types[rbf]-times[2000]-outputsize[256]-gamma[scale]-[svm_time].csv'
df_1 = pd.read_csv(xgboost)
df_2 = pd.read_csv(svm)

plt.xlabel('i')
plt.ylabel('t/s')
# plt.figure(figsize=(20, 6))
# plt.scatter(df['epoch'], df['loss'])
# plt.plot(df['epoch'], df['loss'],color='yellow',alpha=0.5, )
plt.scatter(df_1['i'], df_1['train_time'], label = 'xgboost train')
plt.scatter(df_2['i'], df_2['train_time'], label = 'svm train')
# plt.scatter(df_1['i'], df_1['test_time'], label = 'xgboost test')
plt.scatter(df_2['i'], df_2['test_time'], label = 'svm test')


x_major_locator=MultipleLocator(1)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)

plt.ylim(0,30)
plt.legend()
plt.show()

# %%
import pandas as pd
import time
from AutoEncoder import AutoEncoder
import numpy as np
import torch
import numpy
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from lightcurve import LightCurve
import lightdataset
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from xgboost import plot_importance
from xgboost.sklearn import XGBClassifier
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

model = AutoEncoder(1, 256, 64, 2, 400, 0.25).cuda()
model.load_state_dict(torch.load('./model/2023-03-31-11-32-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[256]--formal.pt'))
dataset = lightdataset.LightDataSet('./data/train_set')
loader = lightdataset.DataLoader(dataset, 64, shuffle=True)
test_dataset = lightdataset.LightDataSet('./data/test_set')
test_loader = lightdataset.DataLoader(test_dataset, 64, shuffle=True)

train_feature = None
train_label = np.array([])
test_feature = None
test_label = np.array([])

for idx, (x, y, name) in enumerate(loader):
    # print(idx)
    x = x.cuda()
    out = model.encode(x).cpu()
    train_feature = np.append(train_feature, out.cpu().detach().numpy(), axis=0) if train_feature is not None else out.cpu().detach().numpy()
    train_label = np.append(train_label, y.cpu().detach().numpy())
    # # train_label.extend(y.cpu().detach().numpy())
    # print(train_label,  train_label.shape)

for idx, (x, y, name) in enumerate(test_loader):
    x = x.cuda()
    out = model.encode(x).cpu()
    test_feature = np.append(test_feature, out.cpu().detach().numpy(), axis=0) if test_feature is not None else out.cpu().detach().numpy()
    test_label = np.append(test_label, y.cpu().detach().numpy())
    # # train_label.extend(y.cpu().detach().numpy())
    # print(test_label,  test_label.shape)

drop_train = []
drop_test = []
# for i in range(len(train_label)):
#     if train_label[i] == -1:
#         print(i)
#         drop_train.append(i)
# for i in range(len(test_label)):
#     if test_label[i] == -1:
#         drop_test.append(i)
for i in range(len(train_label)):
    if train_label[i] not in [0,1,2]:
        print(i)
        drop_train.append(i)
for i in range(len(test_label)):
    if test_label[i] not in [0,1,2]:
        drop_test.append(i)
train_feature=np.delete(train_feature, drop_train, axis=0)
train_label=np.delete(train_label, drop_train, axis=0)
test_feature=np.delete(test_feature, drop_test, axis=0)
test_label=np.delete(test_label, drop_test, axis=0)

parameters = {'learning_rate': 0.3,
              'subsample': 0.8,
              'colsample_bytree': 0.6,
              'max_depth': 8,
              'tree_method': 'gpu_hist'}

clf = XGBClassifier(parameters)
# 在训练集上训练XGBoost模型
clf.fit(train_feature, train_label)

train_predict = clf.predict(train_feature)
test_predict = clf.predict(test_feature)

## 利用accuracy（准确度）【预测正确的样本数目占总预测样本数目的比例】评估模型效果
print('The accuracy of train:', accuracy_score(train_label, train_predict))
print('The accuracy of test:', accuracy_score(test_label, test_predict))

sns.set()
C2= confusion_matrix(test_label, test_predict)
sns.heatmap(C2,annot=True, fmt='d',xticklabels=['EA','EB','EW'], yticklabels=['EA','EB','EW'])
# Out:
# 3006
# 3164
# 3768
# 3974
# 4886
# 9654
# 14982
# C:\Users\zmy\.conda\envs\finalDesign\lib\site-packages\xgboost\core.py:617: FutureWarning: Pass `objective` as keyword args.
#   warnings.warn(msg, FutureWarning)
# The accuracy of train: 1.0
# The accuracy of test: 0.8972505668934241
# <Axes: >

# %%
import pandas as pd
import time
from AutoEncoder import AutoEncoder
import numpy as np
import torch
import numpy
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from lightcurve import LightCurve
import lightdataset
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from xgboost import plot_importance
from xgboost.sklearn import XGBClassifier
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from skelm import ELMClassifier


model = AutoEncoder(1, 256, 64, 2, 400, 0.25).cuda()
model.load_state_dict(torch.load('./model/2023-03-31-11-32-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[256]--formal.pt'))
dataset = lightdataset.LightDataSet('./data/train_set')
loader = lightdataset.DataLoader(dataset, 64, shuffle=True)
test_dataset = lightdataset.LightDataSet('./data/test_set')
test_loader = lightdataset.DataLoader(test_dataset, 64, shuffle=True)

train_feature = None
train_label = np.array([])
test_feature = None
test_label = np.array([])

for idx, (x, y, name) in enumerate(loader):
    # print(idx)
    x = x.cuda()
    out = model.encode(x).cpu()
    train_feature = np.append(train_feature, out.cpu().detach().numpy(), axis=0) if train_feature is not None else out.cpu().detach().numpy()
    train_label = np.append(train_label, y.cpu().detach().numpy())
    # # train_label.extend(y.cpu().detach().numpy())
    # print(train_label,  train_label.shape)

for idx, (x, y, name) in enumerate(test_loader):
    x = x.cuda()
    out = model.encode(x).cpu()
    test_feature = np.append(test_feature, out.cpu().detach().numpy(), axis=0) if test_feature is not None else out.cpu().detach().numpy()
    test_label = np.append(test_label, y.cpu().detach().numpy())
    # # train_label.extend(y.cpu().detach().numpy())
    # print(test_label,  test_label.shape)

drop_train = []
drop_test = []
# for i in range(len(train_label)):
#     if train_label[i] == -1:
#         print(i)
#         drop_train.append(i)
# for i in range(len(test_label)):
#     if test_label[i] == -1:
#         drop_test.append(i)
for i in range(len(train_label)):
    if train_label[i] not in [0,1,2]:
        print(i)
        drop_train.append(i)
for i in range(len(test_label)):
    if test_label[i] not in [0,1,2]:
        drop_test.append(i)
train_feature=np.delete(train_feature, drop_train, axis=0)
train_label=np.delete(train_label, drop_train, axis=0)
test_feature=np.delete(test_feature, drop_test, axis=0)
test_label=np.delete(test_label, drop_test, axis=0)

clf = ELMClassifier(n_neurons=1100)
clf.fit(train_feature,train_label)
train_result = clf.predict(train_feature)
precision = sum(train_result == train_label) / train_label.shape[0]
print('Training precision:', precision, i)

test_result = clf.predict(test_feature)
test_precision = sum(test_result == test_label) / test_label.shape[0]
print('Testing precision:', test_precision)

sns.set()
C2= confusion_matrix(test_label, test_result)
sns.heatmap(C2,annot=True, fmt='d',xticklabels=['EA','EB','EW'], yticklabels=['EA','EB','EW'])
# Out:
# 1632
# 1742
# 2755
# 5131
# 5826
# 10346
# 14982
# Training precision: 0.8574810318664643 7060
# Testing precision: 0.8299319727891157
# <Axes: >

# %%
import pandas as pd
import time
from AutoEncoder import AutoEncoder
import numpy as np
import torch
import numpy
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
from lightcurve import LightCurve
import lightdataset
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from xgboost import plot_importance
from xgboost.sklearn import XGBClassifier
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier


model = AutoEncoder(1, 256, 64, 2, 400, 0.25).cuda()
model.load_state_dict(torch.load('./model/2023-03-31-11-32-types[LSTM]-times[180]-dropout[0.25]-batchsize[64]-hiddensize[64]-outputsize[256]--formal.pt'))
dataset = lightdataset.LightDataSet('./data/train_set')
loader = lightdataset.DataLoader(dataset, 64, shuffle=True)
test_dataset = lightdataset.LightDataSet('./data/test_set')
test_loader = lightdataset.DataLoader(test_dataset, 64, shuffle=True)

train_feature = None
train_label = np.array([])
test_feature = None
test_label = np.array([])

for idx, (x, y, name) in enumerate(loader):
    # print(idx)
    x = x.cuda()
    out = model.encode(x).cpu()
    train_feature = np.append(train_feature, out.cpu().detach().numpy(), axis=0) if train_feature is not None else out.cpu().detach().numpy()
    train_label = np.append(train_label, y.cpu().detach().numpy())
    # # train_label.extend(y.cpu().detach().numpy())
    # print(train_label,  train_label.shape)

for idx, (x, y, name) in enumerate(test_loader):
    x = x.cuda()
    out = model.encode(x).cpu()
    test_feature = np.append(test_feature, out.cpu().detach().numpy(), axis=0) if test_feature is not None else out.cpu().detach().numpy()
    test_label = np.append(test_label, y.cpu().detach().numpy())
    # # train_label.extend(y.cpu().detach().numpy())
    # print(test_label,  test_label.shape)

drop_train = []
drop_test = []
# for i in range(len(train_label)):
#     if train_label[i] == -1:
#         print(i)
#         drop_train.append(i)
# for i in range(len(test_label)):
#     if test_label[i] == -1:
#         drop_test.append(i)
for i in range(len(train_label)):
    if train_label[i] not in [0,1,2]:
        print(i)
        drop_train.append(i)
for i in range(len(test_label)):
    if test_label[i] not in [0,1,2]:
        drop_test.append(i)
train_feature=np.delete(train_feature, drop_train, axis=0)
train_label=np.delete(train_label, drop_train, axis=0)
test_feature=np.delete(test_feature, drop_test, axis=0)
test_label=np.delete(test_label, drop_test, axis=0)

parameters = {'criterion': 'gini',
                'max_features': 18,
                'min_samples_leaf': 1,
                'n_estimators': 250}

clf = RandomForestClassifier(criterion='gini', max_features=1, min_samples_leaf=1, n_estimators=250)

clf.fit(train_feature, train_label)

train_predict = clf.predict(train_feature)
test_predict = clf.predict(test_feature)
test_result = clf.predict(test_feature)
test_precision = sum(test_result == test_label) / test_label.shape[0]
print('Testing precision:', test_precision)

sns.set()
C2= confusion_matrix(test_label, test_result)
sns.heatmap(C2,annot=True, fmt='d',xticklabels=['EA','EB','EW'], yticklabels=['EA','EB','EW'])
# Out:
# 1192
# 6929
# 8208
# 9336
# 9655
# 14378
# 14818
# Testing precision: 0.8037131519274376
# <Axes: >
